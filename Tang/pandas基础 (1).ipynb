# %%
import pandas as pd
import numpy as np


df = pd.read_csv('data/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 返回当前的信息
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 索引
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
# 看列名
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 查看数值
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %% [markdown]
# **series: dataframe 中的一行/列     与 dataframe有同样的属性**

# %%
# 索引我们可以自己指定
df_ = df.set_index('Name')
df_.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, Braund, Mr. Owen Harris to Dooley, Mr. Patrick
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 83.5+ KB

# %%
age = df_['Age']
age
# Out:
# Name
# Braund, Mr. Owen Harris                                22.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    38.0
# Heikkinen, Miss. Laina                                 26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           35.0
# Allen, Mr. William Henry                               35.0
#                                                        ...
# Montvila, Rev. Juozas                                  27.0
# Graham, Miss. Margaret Edith                           19.0
# Johnston, Miss. Catherine Helen "Carrie"                NaN
# Behr, Mr. Karl Howell                                  26.0
# Dooley, Mr. Patrick                                    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# 查看某个人的年龄   ---  查看特定索引对应的值
age["Graham, Miss. Margaret Edith"]
# Out:
# 19.0

# %%
# df 的运算操作  ——广播机制
age = age + 10
age.head()
# Out:
# Name
# Braund, Mr. Owen Harris                                32.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    48.0
# Heikkinen, Miss. Laina                                 36.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           45.0
# Allen, Mr. William Henry                               45.0
# Name: Age, dtype: float64

# %%
age.mean()
# Out:
# 39.69911764705882

# %%
age.max()
# Out:
# 90.0

# %%
age.min()
# Out:
# 10.42

# %%
df_.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 选取多列
df[['Age', 'Fare']][:5]
# Out:
#     Age     Fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **loc用label来定位**
#
# **iloc用position来定位**

# %%
df.loc[: , ['Age','Name', 'Fare']]
# .loc先行后列，中间用逗号（,）分割，例如取 a 和 A 对应的数据
# Out:
#       Age                                               Name     Fare
# 0    22.0                            Braund, Mr. Owen Harris   7.2500
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2    26.0                             Heikkinen, Miss. Laina   7.9250
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4    35.0                           Allen, Mr. William Henry   8.0500
# ..    ...                                                ...      ...
# 886  27.0                              Montvila, Rev. Juozas  13.0000
# 887  19.0                       Graham, Miss. Margaret Edith  30.0000
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"  23.4500
# 889  26.0                              Behr, Mr. Karl Howell  30.0000
# 890  32.0                                Dooley, Mr. Patrick   7.7500
#
# [891 rows x 3 columns]

# %%
df.iloc[0: 5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0: 5, 1:3]
# Out:
#    Survived  Pclass
# 0         0       3
# 1         1       1
# 2         1       3
# 3         1       1
# 4         0       3

# %%
df_
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df_.loc['Behr, Mr. Karl Howell']
# Out:
# PassengerId       890
# Survived            1
# Pclass              1
# Sex              male
# Age              26.0
# SibSp               0
# Parch               0
# Ticket         111369
# Fare             30.0
# Cabin            C148
# Embarked            C
# Name: Behr, Mr. Karl Howell, dtype: object

# %%
df_.loc['Behr, Mr. Karl Howell', 'Fare']
# Out:
# 30.0

# %%
df_.loc['Montvila, Rev. Juozas':'Behr, Mr. Karl Howell', :]
# Out:
#                                           PassengerId  Survived  Pclass  \
# Name
# Montvila, Rev. Juozas                             887         0       2
# Graham, Miss. Margaret Edith                      888         1       1
# Johnston, Miss. Catherine Helen "Carrie"          889         0       3
# Behr, Mr. Karl Howell                             890         1       1
#
#                                              Sex   Age  SibSp  Parch  \
# Name
# Montvila, Rev. Juozas                       male  27.0      0      0
# Graham, Miss. Margaret Edith              female  19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# Behr, Mr. Karl Howell                       male  26.0      0      0
#
#                                               Ticket   Fare Cabin Embarked
# Name
# Montvila, Rev. Juozas                         211536  13.00   NaN        S
# Graham, Miss. Margaret Edith                  112053  30.00   B42        S
# ...

# %%
df_.loc['Behr, Mr. Karl Howell', 'Fare'] = 1000
df_
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %% [markdown]
# **bool类型的索引**

# %%
df_['Fare'] > 4  # 这个相当于索引了
# Out:
# Name
# Braund, Mr. Owen Harris                                True
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    True
# Heikkinen, Miss. Laina                                 True
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           True
# Allen, Mr. William Henry                               True
#                                                        ...
# Montvila, Rev. Juozas                                  True
# Graham, Miss. Margaret Edith                           True
# Johnston, Miss. Catherine Helen "Carrie"               True
# Behr, Mr. Karl Howell                                  True
# Dooley, Mr. Patrick                                    True
# Name: Fare, Length: 891, dtype: bool

# %%
df_[df_['Fare'] > 40]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# McCarthy, Mr. Timothy J                                       7         0
# Fortune, Mr. Charles Alexander                               28         0
# Spencer, Mrs. William Augustus (Marie Eugenie)               32         1
# ...                                                         ...       ...
# Sage, Miss. Dorothy Edith "Dolly"                           864         0
# Roebling, Mr. Washington Augustus II                        868         0
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)            872         1
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880         1
# Behr, Mr. Karl Howell                                       890         1
#
# ...

# %%
df_[df_['Sex'] == 'male'][:5]
# Out:
#                                 PassengerId  Survived  Pclass   Sex   Age  \
# Name
# Braund, Mr. Owen Harris                   1         0       3  male  22.0
# Allen, Mr. William Henry                  5         0       3  male  35.0
# Moran, Mr. James                          6         0       3  male   NaN
# McCarthy, Mr. Timothy J                   7         0       1  male  54.0
# Palsson, Master. Gosta Leonard            8         0       3  male   2.0
#
#                                 SibSp  Parch     Ticket     Fare Cabin  \
# Name
# Braund, Mr. Owen Harris             1      0  A/5 21171   7.2500   NaN
# Allen, Mr. William Henry            0      0     373450   8.0500   NaN
# Moran, Mr. James                    0      0     330877   8.4583   NaN
# McCarthy, Mr. Timothy J             0      0      17463  51.8625   E46
# Palsson, Master. Gosta Leonard      3      1     349909  21.0750   NaN
#
#                                Embarked
# Name
# ...

# %%
# 性别为男的对他们求年龄的平均值

# df_[df_['Sex'] == 'male', 'Age'].mean()   # 报错

df_.loc[df_['Sex'] == 'male', 'Age'].mean()
# Out:
# 30.72664459161148

# %%
# 计算年龄大于 60 的人数
(df_['Age'] > 60).sum()
# Out:
# 22
